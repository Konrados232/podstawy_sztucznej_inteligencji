# %%
import tensorflow as tf
from tensorflow import keras
print(tf.__version__)

print(keras.__version__)
# Out:
# 2.6.0
# 2.6.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
# Wczytaj dane treningowe i testowe
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

train_set = pd.read_csv('Dane/adult/adult.data', sep=", ",header = None)
test_set = pd.read_csv('Dane/adult/adult.test', sep=", ",skiprows = 1, header = None) # Make sure to skip a row for the test set

col_labels = ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 'occupation', 
              'relationship', 'race', 'sex', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
             'wage_class']
train_set.columns = col_labels
test_set.columns = col_labels

train = train_set.replace('?', np.nan).dropna()
test = test_set.replace('?', np.nan).dropna()

train_set.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11296\357239312.py:6: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   train_set = pd.read_csv('Dane/adult/adult.data', sep=", ",header = None)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11296\357239312.py:7: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   test_set = pd.read_csv('Dane/adult/adult.test', sep=", ",skiprows = 1, header = None) # Make sure to skip a row for the test set
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country wage_class
# 0          2174             0              40  United-States      <=50K
# 1             0             0              13  United-States      <=50K
# 2             0             0              40  United-States      <=50K
# 3             0             0              40  United-States      <=50K
# 4             0             0              40           Cuba      <=50K

# %% [markdown]
# # Zad.
# Zróbmy szybki preprocesing

# %%
dataset = pd.concat([train,test])

dataset['wage_class'] = dataset.wage_class.replace({'<=50K.': 0,'<=50K':0, '>50K.':1, '>50K':1})

dataset.drop(["fnlwgt"],axis=1,inplace=True)

dataset.drop(["education"],axis=1,inplace=True)

x = dataset.groupby('native_country')["wage_class"].mean()

d = dict(pd.cut(x[x.index!=" United-States"],5,labels=range(5)))

dataset['native_country'] = dataset['native_country'].replace(d)

dataset = pd.get_dummies(dataset,drop_first=True)

train = dataset.iloc[:train.shape[0]]
test = dataset.iloc[train.shape[0]:]

X_train = train.drop("wage_class",axis=1)
y_train = train.wage_class

X_test = test.drop("wage_class",axis=1)
y_test = test.wage_class

# %%
from keras.models import Sequential
from keras.layers import Dense

from keras.callbacks import History

history = History()
model = Sequential()
model.add(Dense(100,activation="sigmoid", input_shape=(X_train.shape[1],)))
model.add(Dense(50,activation="sigmoid"))
model.add(Dense(10,activation="sigmoid"))
model.add(Dense(1,activation="sigmoid"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               4200
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                510
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 9,771
# Trainable params: 9,771
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="binary_crossentropy", optimizer="Adam", metrics=["accuracy"])

# %%
# history = model.fit(X_train, y_train, epochs=30, validation_data=(X_valid, y_valid))
history = model.fit(X_train, y_train, validation_data= (X_test, y_test), batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 943/943 [==============================] - 15s 8ms/step - loss: 0.5355 - accuracy: 0.7610 - val_loss: 0.5122 - val_accuracy: 0.7749
# Epoch 2/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.4574 - accuracy: 0.7915 - val_loss: 0.3979 - val_accuracy: 0.8044
# Epoch 3/100
# 943/943 [==============================] - 8s 8ms/step - loss: 0.3913 - accuracy: 0.8085 - val_loss: 0.3832 - val_accuracy: 0.8048
# Epoch 4/100
# 943/943 [==============================] - 7s 7ms/step - loss: 0.3769 - accuracy: 0.8156 - val_loss: 0.3653 - val_accuracy: 0.8272
# Epoch 5/100
# 943/943 [==============================] - 7s 7ms/step - loss: 0.3658 - accuracy: 0.8240 - val_loss: 0.3773 - val_accuracy: 0.8193
# Epoch 6/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.3589 - accuracy: 0.8285 - val_loss: 0.3624 - val_accuracy: 0.8187
# Epoch 7/100
# 943/943 [==============================] - 7s 8ms/step - loss: 0.3561 - accuracy: 0.8275 - val_loss: 0.3506 - val_accuracy: 0.8297
# Epoch 8/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.3563 - accuracy: 0.8304 - val_loss: 0.3499 - val_accuracy: 0.8304
# Epoch 9/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.3533 - accuracy: 0.8283 - val_loss: 0.3585 - val_accuracy: 0.8301
# Epoch 10/100
# 943/943 [==============================] - 7s 7ms/step - loss: 0.3510 - accuracy: 0.8299 - val_loss: 0.3511 - val_accuracy: 0.8323
# Epoch 11/100
# 943/943 [==============================] - 7s 7ms/step - loss: 0.3490 - accuracy: 0.8298 - val_loss: 0.3646 - val_accuracy: 0.8171
# Epoch 12/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.3499 - accuracy: 0.8319 - val_loss: 0.3527 - val_accuracy: 0.8303
# Epoch 13/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.3605 - accuracy: 0.8179 - val_loss: 0.3623 - val_accuracy: 0.8165
# Epoch 14/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.
100
# 943/943 [==============================] - 7s 7ms/step - loss: 0.3528 - accuracy: 0.8211 - val_loss: 0.3639 - val_accuracy: 0.8153
# Epoch 76/100
# 943/943 [==============================] - 7s 7ms/step - loss: 0.3529 - accuracy: 0.8203 - val_loss: 0.3674 - val_accuracy: 0.8110
# Epoch 77/100
# 943/943 [==============================] - 7s 8ms/step - loss: 0.3538 - accuracy: 0.8204 - val_loss: 0.3630 - val_accuracy: 0.8147
# Epoch 78/100
# 943/943 [==============================] - 9s 9ms/step - loss: 0.3527 - accuracy: 0.8217 - val_loss: 0.3619 - val_accuracy: 0.8160
# Epoch 79/100
# 943/943 [==============================] - 7s 7ms/step - loss: 0.3517 - accuracy: 0.8204 - val_loss: 0.3752 - val_accuracy: 0.8072
# Epoch 80/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.3531 - accuracy: 0.8191 - val_loss: 0.3626 - val_accuracy: 0.8177
# Epoch 81/100
# 943/943 [==============================] - 5s 6ms/step - loss: 0.3523 - accuracy: 0.8223 - val_loss: 0.3619 - val_accuracy: 0.8161
# Epoch 82/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.3523 - accuracy: 0.8215 - val_loss: 0.3619 - val_accuracy: 0.8161
# Epoch 83/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.3522 - accuracy: 0.8221 - val_loss: 0.3632 - val_accuracy: 0.8152
# Epoch 84/100
# 943/943 [==============================] - 6s 7ms/step - loss: 0.3521 - accuracy: 0.8209 - val_loss: 0.3618 - val_accuracy: 0.8170
# Epoch 85/100
# 943/943 [==============================] - 6s 7ms/step - loss: 0.3518 - accuracy: 0.8216 - val_loss: 0.3634 - val_accuracy: 0.8138
# Epoch 86/100
# 943/943 [==============================] - 8s 9ms/step - loss: 0.3519 - accuracy: 0.8224 - val_loss: 0.3702 - val_accuracy: 0.8122
# Epoch 87/100
# 943/943 [==============================] - 8s 9ms/step - loss: 0.3513 - accuracy: 0.8219 - val_loss: 0.3611 - val_accuracy: 0.8178
# Epoch 88/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.3506 - accuracy: 0.8229 - val_loss: 0.3630 - val_accuracy: 0.8153
# Epoch 89/100
# 943/943 [==============================] - 7s 7ms/step - loss: 0.3514 - accuracy: 0.8219 - val_loss: 0.3623 - val_accuracy: 0.8159
# Epoch 90/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.3509 - accuracy: 0.8224 - val_loss: 0.3617 - val_accuracy: 0.8191
# Epoch 91/100
# 943/943 [==============================] - 5s 6ms/step - loss: 0.3532 - accuracy: 0.8190 - val_loss: 0.3651 - val_accuracy: 0.8153
# Epoch 92/100
# 943/943 [==============================] - 5s 6ms/step - loss: 0.3533 - accuracy: 0.8212 - val_loss: 0.3774 - val_accuracy: 0.8052
# Epoch 93/100
# 943/943 [==============================] - 5s 6ms/step - loss: 0.3526 - accuracy: 0.8207 - val_loss: 0.3637 - val_accuracy: 0.8176
# Epoch 94/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.3531 - accuracy: 0.8199 - val_loss: 0.3672 - val_accuracy: 0.8112
# Epoch 95/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.3513 - accuracy: 0.8217 - val_loss: 0.3618 - val_accuracy: 0.8159
# Epoch 96/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.3530 - accuracy: 0.8203 - val_loss: 0.3648 - val_accuracy: 0.8170
# Epoch 97/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.3518 - accuracy: 0.8212 - val_loss: 0.3636 - val_accuracy: 0.8177
# Epoch 98/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.3503 - accuracy: 0.8218 - val_loss: 0.3613 - val_accuracy: 0.8173
# Epoch 99/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.3511 - accuracy: 0.8214 - val_loss: 0.3614 - val_accuracy: 0.8189
# Epoch 100/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.3514 - accuracy: 0.8214 - val_loss: 0.3639 - val_accuracy: 0.8155

# %%
import pandas as pd

pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %%
model.evaluate(X_test,y_test)
# Out:
# 471/471 [==============================] - 1s 3ms/step - loss: 0.3639 - accuracy: 0.8155
# [0.363851934671402, 0.8154714703559875]

# %%
from sklearn import metrics
metrics.accuracy_score(y_true= y_test, y_pred= (model.predict(X_test) > 0.5).astype("int32") )
# Out:
# 0.8154714475431607

# %% [markdown]
# # Zad
#
# Porównaj powyższy wynik z nauką na danych znormalizowanych.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
model1 = Sequential()
model1.add(Dense(100,activation="sigmoid", input_shape=(X_train_scaled.shape[1],)))
model1.add(Dense(50,activation="sigmoid"))
model1.add(Dense(10,activation="sigmoid"))
model1.add(Dense(1,activation="sigmoid"))
model1.summary()
model1.compile(loss="binary_crossentropy", optimizer="Adam", metrics=["accuracy"])
history1 = model1.fit(X_train_scaled, y_train, validation_data= (X_test_scaled, y_test), batch_size=32, epochs=100)
model1.fit(X_train_scaled, y_train)
predict_x1=model1.predict(X_test_scaled) 
classes_x1=np.argmax(predict_x1,axis=1)
metrics.accuracy_score(y_true= y_test, y_pred=classes_x1)
model1.evaluate(X_test_scaled,y_test)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 100)               4200
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                510
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 9,771
# Trainable params: 9,771
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.3837 - accuracy: 0.8275 - val_loss: 0.3560 - val_accuracy: 0.8305
# Epoch 2/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.3374 - accuracy: 0.8445 - val_loss: 0.3333 - val_accuracy: 0.8469
# Epoch 3/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.3290 - accuracy: 0.8477 - val_loss: 0.3290 - val_accuracy: 0.8470
# Epoch 4/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.3247 - accuracy: 0.8494 - val_loss: 0.3265 - val_accuracy: 0.8474
# Epoch 5/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.3225 - accuracy: 0.8498 - val_loss: 0.3273 - val_accuracy: 0.8479
# Epoch 6/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.3215 - accuracy: 0.8495 - val_loss: 0.3246 - val_accuracy: 0.8479
# Epoch 7/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.3197 - accuracy: 0.8505 - val_loss: 0.3219 - val_accuracy: 0.8497
# Epoch 8/100
# 943/943 [==============================] - 4s 5ms/step - loss: 0.3177 - accuracy: 0.8508 - val_loss: 0.3222 - val_accuracy: 0.8481
# Epoch 9/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.3163 - accuracy: 0.8514 - val_loss: 0.3210 - val_accuracy: 0.8500
# Epoch 10/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.3151 - accuracy: 0.8519 - val_loss: 0.3189 - val_accuracy: 0.8508
# Epoch 11/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.3133 - accuracy: 0.8530 - val_loss: 0.3196 - val_accuracy: 0.8498
# Epoch 12/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.3126 - accuracy: 0.8541 - val_loss: 0.3198 - val_accuracy: 0.8507
# Epoch 13/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.3112 - accuracy: 0.8539 - val_loss: 0.3188 - val_accuracy: 0.8537
# Epoch 14/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.3104 - accuracy: 0.8541 - val_loss: 0.3194 - val_accuracy: 0.8509
# Epoch 15/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.3088 - accuracy: 0.8558 - val_loss: 0.3184 - val_accuracy: 0.8503
# Epoch 16/100
# 943/943 [==============================] - 4s 5ms/step - loss: 0.3084 - accuracy: 0.8556 - val_loss: 0.3194 - val_accuracy: 0.8513
# Epoch 17/100
# 943/943 [==============================] - 7s 7ms/step - loss: 0.3071 - accuracy: 0.8553 - val_loss: 0.3189 - val_accuracy: 0.8503
# Epoch 18/100
# 943/943 [==============================] - 6s 7ms/step - loss: 0.3061 - accuracy: 0.8558 - val_loss: 0.3176 - val_accuracy: 0.8505
# Epoch 19/100
# 943/943 [==============================] - 5s 6ms/step - loss: 0.3055 - accuracy: 0.8582 - val_loss: 0.3178 - val_accuracy: 0.8503
# Epoch 20/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.3044 - accuracy: 0.8565 - val_loss: 0.3169 - val_accuracy: 0.8505
# Epoch 21/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.3033 - accuracy: 0.8580 - val_loss: 0.3172 - val_accuracy: 0.8522
# Epoch 22/100
# 943/943 [==============================] - 5s 6ms/step - loss: 0.3023 - accuracy: 0.8586 - val_loss: 0.3180 - val_accuracy: 0.8519
# Epoch 23/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.3009 - accuracy: 0.8598 - val_loss: 0.3190 - val_accuracy: 0.8517
# Epoch 24/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.3002 - accuracy: 0.8600 - val_loss: 0.3183 - val_accuracy: 0.8494
# Epoch 25/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.2989 - accuracy: 0.8607 - val_loss: 0.3192 - val_accuracy: 0.8507
# Epoch 26/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.2979 - accuracy: 0.8601 - val_loss: 0.3185 - val_accuracy: 0.8528
# Epoch 27/100
# 943/943 [==============================] - 5s 6ms/step - loss: 0.2964 - accuracy: 0.8621 - val_loss: 0.3180 - val_accuracy: 0.8507
# Epoch 28/100
# 943/943 [==============================] - 5s 6ms/step - loss: 0.2957 - accuracy: 0.8613 - val_loss: 0.3207 - val_accuracy: 0.8492
# Epoch 29/100
# 943/943 [==============================] - 7s 7ms/step - loss: 0.2950 - accuracy: 0.8613 - val_loss: 0.3177 - val_accuracy: 0.8521
# Epoch 30/100
# 943/943 [==============================] - 5s 6ms/step - loss: 0.2935 - accuracy: 0.8625 - val_loss: 0.3203 - val_accuracy: 0.8521
# Epoch 31/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.2926 - accuracy: 0.8635 - val_loss: 0.3193 - val_accuracy: 0.8517
# Epoch 32/100
# 943/943 [==============================] - 5s 6ms/step - loss: 0.2918 - accuracy: 0.8633 - val_loss: 0.3192 - val_accuracy: 0.8519
# Epoch 33/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2908 - accuracy: 0.8639 - val_loss: 0.3254 - val_accuracy: 0.8446
# Epoch 34/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2904 - accuracy: 0.8643 - val_loss: 0.3242 - val_accuracy: 0.8521
# Epoch 35/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2894 - accuracy: 0.8643 - val_loss: 0.3216 - val_accuracy: 0.8512
# Epoch 36/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2883 - accuracy: 0.8652 - val_loss: 0.3214 - val_accuracy: 0.8505
# Epoch 37/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2877 - accuracy: 0.8639 - val_loss: 0.3187 - val_accuracy: 0.8538
# Epoch 38/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2865 - accuracy: 0.8656 - val_loss: 0.3208 - val_accuracy: 0.8523
# Epoch 39/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2858 - accuracy: 0.8643 - val_loss: 0.3223 - val_accuracy: 0.8500
# Epoch 40/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2846 - accuracy: 0.8652 - val_loss: 0.3250 - val_accuracy: 0.8493
# Epoch 41/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2832 - accuracy: 0.8674 - val_loss: 0.3264 - val_accuracy: 0.8497
# Epoch 42/100
# 943/943 [==============================] - 4s 5ms/step - loss: 0.2825 - accuracy: 0.8668 - val_loss: 0.3346 - val_accuracy: 0.8501
# Epoch 43/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2821 - accuracy: 0.8673 - val_loss: 0.3268 - val_accuracy: 0.8497
# Epoch 44/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2805 - accuracy: 0.8680 - val_loss: 0.3302 - val_accuracy: 0.8495
# Epoch 45/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2801 - accuracy: 0.8678 - val_loss: 0.3289 - val_accuracy: 0.8501
# Epoch 46/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2793 - accuracy: 0.8684 - val_loss: 0.3288 - val_accuracy: 0.8502
# Epoch 47/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.2780 - accuracy: 0.8689 - val_loss: 0.3336 - val_accuracy: 0.8488
# Epoch 48/100
# 943/943 [==============================] - 5s 6ms/step - loss: 0.2780 - accuracy: 0.8688 - val_loss: 0.3315 - val_accuracy: 0.8482
# Epoch 49/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.2769 - accuracy: 0.8703 - val_loss: 0.3280 - val_accuracy: 0.8516
# Epoch 50/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.2759 - accuracy: 0.8696 - val_loss: 0.3356 - val_accuracy: 0.8471
# Epoch 51/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.2756 - accuracy: 0.8706 - val_loss: 0.3339 - val_accuracy: 0.8491
# Epoch 52/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2743 - accuracy: 0.8702 - val_loss: 0.3315 - val_accuracy: 0.8491
# Epoch 53/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.2735 - accuracy: 0.8714 - val_loss: 0.3381 - val_accuracy: 0.8468
# Epoch 54/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.2725 - accuracy: 0.8713 - val_loss: 0.3373 - val_accuracy: 0.8473
# Epoch 55/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2725 - accuracy: 0.8715 - val_loss: 0.3373 - val_accuracy: 0.8495
# Epoch 56/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2714 - accuracy: 0.8714 - val_loss: 0.3378 - val_accuracy: 0.8491
# Epoch 57/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2706 - accuracy: 0.8730 - val_loss: 0.3370 - val_accuracy: 0.8493
# Epoch 58/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2701 - accuracy: 0.8713 - val_loss: 0.3386 - val_accuracy: 0.8492
# Epoch 59/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2694 - accuracy: 0.8726 - val_loss: 0.3415 - val_accuracy: 0.8473
# Epoch 60/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2683 - accuracy: 0.8725 - val_loss: 0.3467 - val_accuracy: 0.8465
# Epoch 61/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2672 - accuracy: 0.8730 - val_loss: 0.3433 - val_accuracy: 0.8448
# Epoch 62/100
# 943/943 [==============================] - 5s 6ms/step - loss: 0.2668 - accuracy: 0.8736 - val_loss: 0.3453 - val_accuracy: 0.8482
# Epoch 63/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.2661 - accuracy: 0.8749 - val_loss: 0.3475 - val_accuracy: 0.8448
# Epoch 64/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2651 - accuracy: 0.8731 - val_loss: 0.3437 - val_accuracy: 0.8491
# Epoch 65/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2648 - accuracy: 0.8743 - val_loss: 0.3458 - val_accuracy: 0.8471
# Epoch 66/100
# 943/943 [==============================] - 7s 7ms/step - loss: 0.2643 - accuracy: 0.8739 - val_loss: 0.3460 - val_accuracy: 0.8456
# Epoch 67/100
# 943/943 [==============================] - 7s 7ms/step - loss: 0.2630 - accuracy: 0.8763 - val_loss: 0.3506 - val_accuracy: 0.8481
# Epoch 68/100
# 943/943 [==============================] - 6s 7ms/step - loss: 0.2630 - accuracy: 0.8754 - val_loss: 0.3512 - val_accuracy: 0.8481
# Epoch 69/100
# 943/943 [==============================] - 7s 7ms/step - loss: 0.2621 - accuracy: 0.8764 - val_loss: 0.3506 - val_accuracy: 0.8473
# Epoch 70/100
# 943/943 [==============================] - 6s 7ms/step - loss: 0.2609 - accuracy: 0.8763 - val_loss: 0.3568 - val_accuracy: 0.8442
# Epoch 71/100
# 943/943 [==============================] - 6s 7ms/step - loss: 0.2605 - accuracy: 0.8761 - val_loss: 0.3525 - val_accuracy: 0.8434
# Epoch 72/100
# 943/943 [==============================] - 7s 7ms/step - loss: 0.2600 - accuracy: 0.8767 - val_loss: 0.3568 - val_accuracy: 0.8473
# Epoch 73/100
# 943/943 [==============================] - 6s 7ms/step - loss: 0.2597 - accuracy: 0.8767 - val_loss: 0.3584 - val_accuracy: 0.8463
# Epoch 74/100
# 943/943 [==============================] - 6s 7ms/step - loss: 0.2590 - accuracy: 0.8763 - val_loss: 0.3655 - val_accuracy: 0.8384
# Epoch 75/100
# 943/943 [==============================] - 5s 6ms/step - loss: 0.2580 - accuracy: 0.8782 - val_loss: 0.3631 - val_accuracy: 0.8471
# Epoch 76/100
# 943/943 [==============================] - 4s 5ms/step - loss: 0.2581 - accuracy: 0.8766 - val_loss: 0.3558 - val_accuracy: 0.8459
# Epoch 77/100
# 943/943 [==============================] - 4s 5ms/step - loss: 0.2568 - accuracy: 0.8775 - val_loss: 0.3575 - val_accuracy: 0.8456
# Epoch 78/100
# 943/943 [==============================] - 4s 5ms/step - loss: 0.2563 - accuracy: 0.8781 - val_loss: 0.3571 - val_accuracy: 0.8444
# Epoch 79/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2555 - accuracy: 0.8784 - val_loss: 0.3612 - val_accuracy: 0.8468
# Epoch 80/100
# 943/943 [==============================] - 5s 6ms/step - loss: 0.2550 - accuracy: 0.8789 - val_loss: 0.3634 - val_accuracy: 0.8448
# Epoch 81/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2545 - accuracy: 0.8791 - val_loss: 0.3681 - val_accuracy: 0.8419
# Epoch 82/100
# 943/943 [==============================] - 4s 4ms/step - loss: 0.2546 - accuracy: 0.8798 - val_loss: 0.3671 - val_accuracy: 0.8471
# Epoch 83/100
# 943/943 [==============================] - 4s 4ms/step - loss: 0.2527 - accuracy: 0.8800 - val_loss: 0.3717 - val_accuracy: 0.8417
# Epoch 84/100
# 943/943 [==============================] - 4s 4ms/step - loss: 0.2526 - accuracy: 0.8796 - val_loss: 0.3682 - val_accuracy: 0.8455
# Epoch 85/100
# 943/943 [==============================] - 4s 5ms/step - loss: 0.2525 - accuracy: 0.8797 - val_loss: 0.3758 - val_accuracy: 0.8418
# Epoch 86/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2515 - accuracy: 0.8801 - val_loss: 0.3734 - val_accuracy: 0.8454
# Epoch 87/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2512 - accuracy: 0.8805 - val_loss: 0.3678 - val_accuracy: 0.8451
# Epoch 88/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2505 - accuracy: 0.8807 - val_loss: 0.3738 - val_accuracy: 0.8422
# Epoch 89/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.2495 - accuracy: 0.8801 - val_loss: 0.3774 - val_accuracy: 0.8418
# Epoch 90/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.2492 - accuracy: 0.8816 - val_loss: 0.3753 - val_accuracy: 0.8423
# Epoch 91/100
# 943/943 [==============================] - 4s 4ms/step - loss: 0.2490 - accuracy: 0.8813 - val_loss: 0.3755 - val_accuracy: 0.8425
# Epoch 92/100
# 943/943 [==============================] - 4s 4ms/step - loss: 0.2476 - accuracy: 0.8820 - val_loss: 0.3766 - val_accuracy: 0.8443
# Epoch 93/100
# 943/943 [==============================] - 5s 6ms/step - loss: 0.2483 - accuracy: 0.8815 - val_loss: 0.3782 - val_accuracy: 0.8442
# Epoch 94/100
# 943/943 [==============================] - 5s 6ms/step - loss: 0.2469 - accuracy: 0.8823 - val_loss: 0.3811 - val_accuracy: 0.8443
# Epoch 95/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2468 - accuracy: 0.8814 - val_loss: 0.3817 - val_accuracy: 0.8374
# Epoch 96/100
# 943/943 [==============================] - 8s 9ms/step - loss: 0.2464 - accuracy: 0.8824 - val_loss: 0.3878 - val_accuracy: 0.8408
# Epoch 97/100
# 943/943 [==============================] - 6s 6ms/step - loss: 0.2460 - accuracy: 0.8823 - val_loss: 0.3809 - val_accuracy: 0.8432
# Epoch 98/100
# 943/943 [==============================] - 4s 5ms/step - loss: 0.2458 - accuracy: 0.8840 - val_loss: 0.3859 - val_accuracy: 0.8463
# Epoch 99/100
# 943/943 [==============================] - 5s 5ms/step - loss: 0.2445 - accuracy: 0.8822 - val_loss: 0.3878 - val_accuracy: 0.8458
# Epoch 100/100
# 943/943 [==============================] - 5s 6ms/step - loss: 0.2441 - accuracy: 0.8822 - val_loss: 0.3889 - val_accuracy: 0.8426
# 943/943 [==============================] - 4s 4ms/step - loss: 0.2435 - accuracy: 0.8842
# 471/471 [==============================] - 1s 3ms/step - loss: 0.3875 - accuracy: 0.8409
# [0.3875350058078766, 0.8409030437469482]

# %% [markdown]
# # Zad.
# Stwórz wykres porównujący metody.

# %%
plt.plot(history1.history['accuracy'], label = "scaled")
plt.plot(history1.history['val_accuracy'], label = "scaled")
plt.plot(history.history['accuracy'], label = "first")
plt.plot(history.history['val_accuracy'], label = "first")
plt.legend()

plt.show()
