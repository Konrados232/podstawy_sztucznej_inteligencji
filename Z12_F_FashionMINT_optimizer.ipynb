# %%
import tensorflow as tf
from tensorflow import keras
print(tf.__version__)

print(keras.__version__)
# Out:
# 2.6.0
# 2.6.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
fashion_mnist = keras.datasets.fashion_mnist
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist.load_data()

# %%
X_train_full.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# Each pixel intensity is represented as a byte (0 to 255):

# %%
X_train_full.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# * Podzielmy pełny zestaw treningowy na zestaw walidacyjny i zestaw treningowy.
# * Kolor pikseli skalujemy również do zakresu 0-1 i przekształcamy na zmiennoprzecinkowe, dzieląc przez 255.

# %%
X_valid, X_train = X_train_full[:5000] / 255., X_train_full[5000:] / 255.
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]
X_test = X_test / 255.

# %%
plt.imshow(X_train[0], cmap="binary")
plt.axis('off')
plt.show()

# %%
y_train
# Out:
# array([4, 0, 7, ..., 3, 0, 5], dtype=uint8)

# %% [markdown]
# Będziemy używać klas numerycznych i nazw.

# %%
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

class_names[y_train[0]]
# Out:
# 'Coat'

# %% [markdown]
# Możemy narysować więcej przykładów treningowych.

# %%
n_rows = 4
n_cols = 10
plt.figure(figsize=(n_cols * 1.2, n_rows * 1.2))
for row in range(n_rows):
    for col in range(n_cols):
        index = n_cols * row + col
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(X_train[index], cmap="binary", interpolation="nearest")
        plt.axis('off')
        plt.title(class_names[y_train[index]], fontsize=12)
plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()

# %% [markdown]
# # Zad
# Porównaj wyniki działań różnych optymalizacji
# *
# ```python
# sgd = keras.optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
# ```
# *
# ```python
# Adam = keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)
# ```
# *
# ```python
# Adam = keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, amsgrad=False)
# ```
#
# https://keras.io/optimizers/

# %%
from keras.models import Sequential
from keras.layers import Dense

from keras.callbacks import History

history_sgd = History()
model = Sequential()
model.add(Dense(100,activation="sigmoid",input_shape=(X_train.shape[1],)))
model.add(Dense(50,activation="sigmoid"))
model.add(Dense(10,activation="sigmoid"))
model.add(Dense(1,activation="sigmoid"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               2900
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                510
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 8,471
# Trainable params: 8,471
# Non-trainable params: 0
# _________________________________________________________________

# %%
sgd = keras.optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss="binary_crossentropy",optimizer=sgd, metrics=["accuracy"])
model.fit(X_train, y_train, validation_data= (X_test, y_test), batch_size=32,epochs=100, callbacks=[history_sgd])

history_sgd.history.keys()

import matplotlib.pyplot as pl
plt.plot(history_sgd.history['accuracy'], label = "tarina")
plt.plot(history_sgd.history['val_accuracy'], label = "test")
plt.legend()
plt.show()

import matplotlib.pyplot as pl
plt.plot(history_sgd.history['loss'], label = "tarina")
plt.plot(history_sgd.history['val_loss'], label = "test")
plt.legend()
plt.show()
# Out:
# d:\AppTrue\Anaconda\envs\tf_gpu\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Epoch 1/100
# WARNING:tensorflow:Model was constructed with shape (None, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28), dtype=tf.float32, name='dense_input'), name='dense_input', description="created by layer 'dense_input'"), but it was called on an input with incompatible shape (None, 28, 28).
# WARNING:tensorflow:Model was constructed with shape (None, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28), dtype=tf.float32, name='dense_input'), name='dense_input', description="created by layer 'dense_input'"), but it was called on an input with incompatible shape (None, 28, 28).
# 1719/1719 [==============================] - ETA: 0s - loss: -53.0949 - accuracy: 0.0990WARNING:tensorflow:Model was constructed with shape (None, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28), dtype=tf.float32, name='dense_input'), name='dense_input', description="created by layer 'dense_input'"), but it was called on an input with incompatible shape (None, 28, 28).
# 1719/1719 [==============================] - 287s 76ms/step - loss: -53.0949 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 2/100
# 1719/1719 [==============================] - 118s 68ms/step - loss: -53.3728 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 3/100
# 1719/1719 [==============================] - 106s 62ms/step - loss: -53.3728 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 4/100
# 1719/1719 [==============================] - 106s 62ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 5/100
# 1719/1719 [==============================] - 116s 68ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 6/100
# 1719/1719 [==============================] - 99s 58ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 7/100
# 1719/1719 [==============================] - 95s 56ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 8/100
# 1719/1719 [==============================] - 93s 54ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 9/100
# 1719/1719 [==============================] - 95s 55ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 10/100
# 1719/1719 [==============================] - 96s 56ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 11/100
# 1719/1719 [==============================] - 91s 53ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 12/100
# 1719/1719 [==============================] - 89s 52ms/step - loss: -53.3728 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 13/100
# 1719/1719 [==============================] - 90s 52ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 14/100
# 1719/1719 [==============================] - 76s 43ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 15/100
# 1719/1719 [==============================] - 48s 28ms/step - loss: -53.3728 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 16/100
# 1719/1719 [==============================] - 46s 27ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 17/100
# 1719/1719 [==============================] - 48s 28ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 18/100
# 1719/1719 [==============================] - 47s 27ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 19/100
# 1719/1719 [==============================] - 46s 27ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 20/100
# 1719/1719 [==============================] - 46s 27ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 21/100
# 1719/1719 [==============================] - 48s 28ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 22/100
# 1719/1719 [==============================] - 46s 27ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 23/100
# 1719/1719 [==============================] - 49s 29ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 24/100
# 1719/1719 [==============================] - 44s 26ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 25/100
# 1719/1719 [==============================] - 42s 25ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 26/100
# 1719/1719 [==============================] - 44s 25ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 27/100
# 1719/1719 [==============================] - 45s 26ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 28/100
# 1719/1719 [==============================] - 43s 25ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 29/100
# 1719/1719 [==============================] - 44s 25ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 30/100
# 1719/1719 [==============================] - 45s 26ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 31/100
# 1719/1719 [==============================] - 45s 26ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 32/100
# 1719/1719 [==============================] - 43s 25ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 33/100
# 1719/1719 [==============================] - 44s 25ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 34/100
# 1719/1719 [==============================] - 45s 26ms/step - loss: -53.3728 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 35/100
# 1719/1719 [==============================] - 44s 25ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 36/100
# 1719/1719 [==============================] - 52s 30ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 37/100
# 1719/1719 [==============================] - 54s 31ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 38/100
# 1719/1719 [==============================] - 44s 26ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 39/100
# 1719/1719 [==============================] - 45s 26ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 40/100
# 1719/1719 [==============================] - 44s 26ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 41/100
# 1719/1719 [==============================] - 43s 25ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 42/100
# 1719/1719 [==============================] - 44s 25ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 43/100
# 1719/1719 [==============================] - 44s 26ms/step - loss: -53.3728 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 44/100
# 1719/1719 [==============================] - 45s 26ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 45/100
# 1719/1719 [==============================] - 59s 35ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 46/100
# 1719/1719 [==============================] - 62s 36ms/step - loss: -53.3728 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 47/100
# 1719/1719 [==============================] - 72s 42ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 48/100
# 1719/1719 [==============================] - 105s 61ms/step - loss: -53.3728 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 49/100
# 1719/1719 [==============================] - 101s 59ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 50/100
# 1719/1719 [==============================] - 99s 58ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 51/100
# 1719/1719 [==============================] - 102s 59ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 52/100
# 1719/1719 [==============================] - 99s 58ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 53/100
# 1719/1719 [==============================] - 102s 59ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 54/100
# 1719/1719 [==============================] - 110s 64ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 55/100
# 1719/1719 [==============================] - 107s 62ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 56/100
# 1719/1719 [==============================] - 106s 62ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 57/100
# 1719/1719 [==============================] - 106s 62ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 58/100
# 1719/1719 [==============================] - 101s 59ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 59/100
# 1719/1719 [==============================] - 29s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 60/100
# 1719/1719 [==============================] - 29s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 61/100
# 1719/1719 [==============================] - 29s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 62/100
# 1719/1719 [==============================] - 30s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 63/100
# 1719/1719 [==============================] - 26s 15ms/step - loss: -53.3728 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 64/100
# 1719/1719 [==============================] - 27s 15ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 65/100
# 1719/1719 [==============================] - 29s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 66/100
# 1719/1719 [==============================] - 29s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 67/100
# 1719/1719 [==============================] - 29s 17ms/step - loss: -53.3728 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 68/100
# 1719/1719 [==============================] - 27s 15ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 69/100
# 1719/1719 [==============================] - 27s 15ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 70/100
# 1719/1719 [==============================] - 26s 15ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 71/100
# 1719/1719 [==============================] - 26s 15ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 72/100
# 1719/1719 [==============================] - 34s 20ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 73/100
# 1719/1719 [==============================] - 41s 24ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 74/100
# 1719/1719 [==============================] - 34s 20ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 75/100
# 1719/1719 [==============================] - 27s 16ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 76/100
# 1719/1719 [==============================] - 28s 16ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 77/100
# 1719/1719 [==============================] - 29s 17ms/step - loss: -53.3728 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 78/100
# 1719/1719 [==============================] - 28s 16ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 79/100
# 1719/1719 [==============================] - 28s 16ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 80/100
# 1719/1719 [==============================] - 28s 16ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 81/100
# 1719/1719 [==============================] - 28s 16ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 82/100
# 1719/1719 [==============================] - 28s 16ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 83/100
# 1719/1719 [==============================] - 29s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 84/100
# 1719/1719 [==============================] - 28s 16ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 85/100
# 1719/1719 [==============================] - 28s 16ms/step - loss: -53.3728 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 86/100
# 1719/1719 [==============================] - 28s 16ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 87/100
# 1719/1719 [==============================] - 28s 16ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 88/100
# 1719/1719 [==============================] - 28s 16ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 89/100
# 1719/1719 [==============================] - 27s 16ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 90/100
# 1719/1719 [==============================] - 28s 16ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 91/100
# 1719/1719 [==============================] - 28s 16ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 92/100
# 1719/1719 [==============================] - 28s 16ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 93/100
# 1719/1719 [==============================] - 28s 16ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 94/100
# 1719/1719 [==============================] - 28s 16ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 95/100
# 1719/1719 [==============================] - 28s 16ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 96/100
# 1719/1719 [==============================] - 28s 16ms/step - loss: -53.3728 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 97/100
# 1719/1719 [==============================] - 28s 16ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 98/100
# 1719/1719 [==============================] - 29s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 99/100
# 1719/1719 [==============================] - 29s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 100/100
# 1719/1719 [==============================] - 29s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000

# %%
history_Adam1 = History()
model = Sequential()
model.add(Dense(100,activation="sigmoid",input_shape=(X_train.shape[1],)))
model.add(Dense(50,activation="sigmoid"))
model.add(Dense(10,activation="sigmoid"))
model.add(Dense(1,activation="sigmoid"))
model.summary()
Adam = keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)
model.compile(loss="binary_crossentropy",optimizer=Adam, metrics=["accuracy"])

model.fit(X_train, y_train, validation_data= (X_test, y_test), batch_size=32,epochs=30, callbacks=[history_Adam1])


plt.plot(history_Adam1.history['accuracy'], label = "tarina")
plt.plot(history_Adam1.history['val_accuracy'], label = "test")
plt.legend()
plt.show()
plt.plot(history_Adam1.history['loss'], label = "tarina")
plt.plot(history_Adam1.history['val_loss'], label = "test")
plt.legend()
plt.show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 100)               2900
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                510
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 8,471
# Trainable params: 8,471
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# WARNING:tensorflow:Model was constructed with shape (None, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28), dtype=tf.float32, name='dense_4_input'), name='dense_4_input', description="created by layer 'dense_4_input'"), but it was called on an input with incompatible shape (None, 28, 28).
# WARNING:tensorflow:Model was constructed with shape (None, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28), dtype=tf.float32, name='dense_4_input'), name='dense_4_input', description="created by layer 'dense_4_input'"), but it was called on an input with incompatible shape (None, 28, 28).
# 1716/1719 [============================>.] - ETA: 0s - loss: -17.7903 - accuracy: 0.0988WARNING:tensorflow:Model was constructed with shape (None, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28), dtype=tf.float32, name='dense_4_input'), name='dense_4_input', description="created by layer 'dense_4_input'"), but it was called on an input with incompatible shape (None, 28, 28).
# 1719/1719 [==============================] - 27s 15ms/step - loss: -17.8113 - accuracy: 0.0987 - val_loss: -34.4235 - val_accuracy: 0.1000
# Epoch 2/30
# 1719/1719 [==============================] - 29s 17ms/step - loss: -48.7085 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 3/30
# 1719/1719 [==============================] - 29s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 4/30
# 1719/1719 [==============================] - 28s 16ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 5/30
# 1719/1719 [==============================] - 28s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 6/30
# 1719/1719 [==============================] - 29s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 7/30
# 1719/1719 [==============================] - 28s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 8/30
# 1719/1719 [==============================] - 29s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 9/30
# 1719/1719 [==============================] - 29s 17ms/step - loss: -53.3728 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 10/30
# 1719/1719 [==============================] - 28s 16ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 11/30
# 1719/1719 [==============================] - 28s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 12/30
# 1719/1719 [==============================] - 28s 16ms/step - loss: -53.3728 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 13/30
# 1719/1719 [==============================] - 28s 16ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 14/30
# 1719/1719 [==============================] - 28s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 15/30
# 1719/1719 [==============================] - 29s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 16/30
# 1719/1719 [==============================] - 28s 16ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 17/30
# 1719/1719 [==============================] - 29s 17ms/step - loss: -53.3728 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 18/30
# 1719/1719 [==============================] - 29s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 19/30
# 1719/1719 [==============================] - 29s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 20/30
# 1719/1719 [==============================] - 28s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 21/30
# 1719/1719 [==============================] - 28s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 22/30
# 1719/1719 [==============================] - 28s 16ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 23/30
# 1719/1719 [==============================] - 28s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 24/30
# 1719/1719 [==============================] - 29s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 25/30
# 1719/1719 [==============================] - 29s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 26/30
# 1719/1719 [==============================] - 29s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 27/30
# 1719/1719 [==============================] - 29s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 28/30
# 1719/1719 [==============================] - 28s 17ms/step - loss: -53.3728 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 29/30
# 1719/1719 [==============================] - 29s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000
# Epoch 30/30
# 1719/1719 [==============================] - 29s 17ms/step - loss: -53.3727 - accuracy: 0.0990 - val_loss: -53.3723 - val_accuracy: 0.1000

# %%
Adam2 = keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, amsgrad=False)
