# %% [markdown]
# # 2-wymiarowy rozkład Normalny

# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy.random as rnd
import scipy.stats as stats
from scipy.stats import multivariate_normal

# %% [markdown]
# # Zadanie
# Proszę wygenerować próbkę z rozkładu Normalnego
# $$
# m = [0,0]
# $$
#
# oraz
#
# $$
# \Sigma = [[4.40, -2.75], [-2.75,  5.50]]
# $$

# %%
mean1 = np.array([0, 0])
cov1 = np.array([[4.40, -2.75], [-2.75,  5.50]])
X1_rv=multivariate_normal(mean1, cov1)
X = X1_rv.rvs(1000)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5, 5))
ax.scatter(X[:, 0], X[:, 1])
ax.set_xlim([-10,10])
ax.set_ylim([-10,10])
plt.show()

# %% [markdown]
# # Zadanie
# Proszę policzyć średnią oraz macierz kowariancji próbki.

# %%
means = X.mean(axis=0)
cov = np.cov(X.T)

print(means)
print(cov)
# Out:
# <class 'numpy.ndarray'>
# [ 0.11120826 -0.10623318]
# [[ 4.58432309 -2.86429395]
#  [-2.86429395  5.50700064]]

# %% [markdown]
# # Zadanie
# Proszę zdefiniować zmienną losową o razkładzie zadanym na podstawie empirycznej średniej i kowariancji oraz narysować na jednym wykresie:
#
# - próbkę
# - poziomice rozkładu normalnego

# %%
# mean and covariance
X2_mean = means
X2_covariance_matrix = cov

X2_rv=multivariate_normal(means, cov)
X2 = X2_rv.rvs(1000)

# contours
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)

X, Y = np.meshgrid(x,y)

pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X; pos[:, :, 1] = Y

# plot
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5, 5))

# sample
ax.scatter(X2[:, 0], X2[:, 1])

# contours
ax.contour(X, Y, X2_rv.pdf(pos), levels=8, colors='red')

ax.set_xlim([-10,10])
ax.set_ylim([-10,10])
plt.show()

# %% [markdown]
# # Zadanie
# Policz wektory i wartości własne macierzy kowariancji. Narysuj na jednym wykresie
#
# - próbkę
# - poziomice rozkładu normalnego
# - wektory własne macierzy kowariancji

# %%
# mean and covariance
cov_mean = means
covariance_matrix = cov

X3_rv = multivariate_normal(cov_mean, covariance_matrix)
X3 = X3_rv.rvs(1000)

# contours
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)

X, Y = np.meshgrid(x,y)

pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X; pos[:, :, 1] = Y

# eigen values
eig = np.linalg.eig(covariance_matrix)
eigenvalues = eig[0]
eigenvectors = eig[1] * 10

# plot
origin_point = np.array([[0, 0],[0, 0]])
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5, 5))

# sample
ax.scatter(X3[:, 0], X3[:, 1])

# contours
ax.contour(X, Y, X3_rv.pdf(pos), levels=5, colors='red')

# eigenvectors
ax.quiver(*origin_point, eigenvectors[0], eigenvectors[1], scale=30)


ax.set_xlim([-10,10])
ax.set_ylim([-10,10])
plt.show()

# %% [markdown]
# # Zadanie
# Proszę wygenerować próbkę na kwadracie $[0,1] \times [0,1]$.
# Następnie proszę policzyć średnią oraz macierz kowariancji próbki.
#
# Narysuj na jednym wykresie
#
# - próbkę
# - poziomice rozkładu normalnego
# - wektory własne macierzy kowariancji

# %%
# sample
x_cord = np.random.random(1000)
y_cord = np.random.random(1000)

positions = np.array(list(zip(x_cord, y_cord)))

# mean and covariance
cov_mean = positions.mean(axis=0)
covariance_matrix = np.cov(positions.T)

print(cov_mean)
print(covariance_matrix)

# contours
X4_rv = multivariate_normal(cov_mean, covariance_matrix)

x = np.linspace(0,1,100)
y = np.linspace(0,1,100)

X, Y = np.meshgrid(x,y)

pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X; pos[:, :, 1] = Y


# eigen values
eig = np.linalg.eig(covariance_matrix)
eigenvalues = eig[0]
eigenvectors = eig[1] * 10


# plot
origin_point = np.array([[0.5,0.5],[0.5,0.5]])
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5, 5))
# sample
ax.scatter(x_cord, y_cord)

# contours
ax.contour(X, Y, X4_rv.pdf(pos), levels=8, colors='red')

# eigenvectors
ax.quiver(*origin_point, eigenvectors[0], eigenvectors[1], scale=30)


ax.set_xlim([0,1])
ax.set_ylim([0,1])
plt.show()
# Out:
# [0.50755331 0.50278411]
# [[0.08081917 0.00556087]
#  [0.00556087 0.07981202]]
